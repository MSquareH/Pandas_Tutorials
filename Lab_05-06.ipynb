# %% [markdown]
# # Rename

# %%
import pandas as pd
import os

# %%
os.chdir('C:/Users/Moiz_Ali_Abedin/Desktop/Files of Pandas')

# %%
ds=pd.read_excel(r'Sales.xls')

# %%
ds.head()
# Out:
#    Order ID           Order Date Order Priority Order Quantity    Sales  \
# 0       3.0                 Male            Low              6   261.54
# 1     293.0  2012-10-01 00:00:00           High             49    10123
# 2     293.0  2012-10-01 00:00:00           High             27   244.57
# 3     483.0  2011-07-10 00:00:00           High            NaN  4965.76
# 4     515.0  2010-08-28 00:00:00  Not Specified             19   394.27
#
#    Discount       Ship Mode   Profit  Unit Price Shipping Cost  \
# 0      0.04     Regular Air  -213.25       38.94            35
# 1      0.07  Delivery Truck   457.81      208.16         68.02
# 2      0.01     Regular Air  46.7075        8.69          2.99
# 3      0.08     Regular Air  1198.97      195.99          3.99
# 4      0.08     Regular Air    30.94       21.78          5.94
#
#     Customer Name Province   Region Customer Segment Product Category  \
# 0           25000  Nunavut  Nunavut   Small Business  Office Supplies
# ...

# %%
ds.columns
# Out:
# Index(['Order ID', 'Order Date', 'Order Priority', 'Order Quantity', 'Sales',
#        'Discount', 'Ship Mode', 'Profit', 'Unit Price', 'Shipping Cost',
#        'Customer Name', 'Province', 'Region', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Name',
#        'Product Container', 'Ship Date'],
#       dtype='object')

# %%
ds=ds.rename(columns={'Order Quantity':'Order_Quantity','Product Name':'Prod_Name'})

# %%
ds.head()
# Out:
#    Order ID           Order Date Order Priority Order_Quantity    Sales  \
# 0       3.0                 Male            Low              6   261.54
# 1     293.0  2012-10-01 00:00:00           High             49    10123
# 2     293.0  2012-10-01 00:00:00           High             27   244.57
# 3     483.0  2011-07-10 00:00:00           High            NaN  4965.76
# 4     515.0  2010-08-28 00:00:00  Not Specified             19   394.27
#
#    Discount       Ship Mode   Profit  Unit Price Shipping Cost  \
# 0      0.04     Regular Air  -213.25       38.94            35
# 1      0.07  Delivery Truck   457.81      208.16         68.02
# 2      0.01     Regular Air  46.7075        8.69          2.99
# 3      0.08     Regular Air  1198.97      195.99          3.99
# 4      0.08     Regular Air    30.94       21.78          5.94
#
#     Customer Name Province   Region Customer Segment Product Category  \
# 0           25000  Nunavut  Nunavut   Small Business  Office Supplies
# ...

# %%
ds.columns=ds.columns.str.replace(' ','_')

# %% [markdown]
# # Remove Column

# %%
ds=ds.drop('Order_ID',axis=1)

# %%
ds.head()
# Out:
#             Order_Date Order_Priority Order_Quantity    Sales  Discount  \
# 0                 Male            Low              6   261.54      0.04
# 1  2012-10-01 00:00:00           High             49    10123      0.07
# 2  2012-10-01 00:00:00           High             27   244.57      0.01
# 3  2011-07-10 00:00:00           High            NaN  4965.76      0.08
# 4  2010-08-28 00:00:00  Not Specified             19   394.27      0.08
#
#         Ship_Mode   Profit  Unit_Price Shipping_Cost   Customer_Name Province  \
# 0     Regular Air  -213.25       38.94            35           25000  Nunavut
# 1  Delivery Truck   457.81      208.16         68.02    Barry French  Nunavut
# 2     Regular Air  46.7075        8.69          2.99    Barry French  Nunavut
# 3     Regular Air  1198.97      195.99          3.99   Clay Rozendal  Nunavut
# 4     Regular Air    30.94       21.78          5.94  Carlos Soltero  Nunavut
#
# ...

# %%
del ds['Order_Date']

# %%
ds.head()
# Out:
#   Order_Priority Order_Quantity    Sales  Discount       Ship_Mode   Profit  \
# 0            Low              6   261.54      0.04     Regular Air  -213.25
# 1           High             49    10123      0.07  Delivery Truck   457.81
# 2           High             27   244.57      0.01     Regular Air  46.7075
# 3           High            NaN  4965.76      0.08     Regular Air  1198.97
# 4  Not Specified             19   394.27      0.08     Regular Air    30.94
#
#    Unit_Price Shipping_Cost   Customer_Name Province   Region  \
# 0       38.94            35           25000  Nunavut  Nunavut
# 1      208.16         68.02    Barry French  Nunavut  Nunavut
# 2        8.69          2.99    Barry French  Nunavut  Nunavut
# 3      195.99          3.99   Clay Rozendal  Nunavut  Nunavut
# 4       21.78          5.94  Carlos Soltero  Nunavut  Nunavut
#
#   Customer_Segment Product_Category            Product_Sub-Category  \
# ...

# %%
ds=ds.drop(['Order_Priority','Sales'],axis=1)

# %%
ds.head()
# Out:
#   Order_Quantity  Discount       Ship_Mode   Profit  Unit_Price Shipping_Cost  \
# 0              6      0.04     Regular Air  -213.25       38.94            35
# 1             49      0.07  Delivery Truck   457.81      208.16         68.02
# 2             27      0.01     Regular Air  46.7075        8.69          2.99
# 3            NaN      0.08     Regular Air  1198.97      195.99          3.99
# 4             19      0.08     Regular Air    30.94       21.78          5.94
#
#     Customer_Name Province   Region Customer_Segment Product_Category  \
# 0           25000  Nunavut  Nunavut   Small Business  Office Supplies
# 1    Barry French  Nunavut  Nunavut         Consumer  Office Supplies
# 2    Barry French  Nunavut  Nunavut         Consumer  Office Supplies
# 3   Clay Rozendal  Nunavut  Nunavut        Corporate       Technology
# 4  Carlos Soltero  Nunavut  Nunavut         Consumer  Office Supplies
#
#              Product_Sub-Category  \
# 0          Storage & Organization
# ...

# %%
ds=ds.drop(ds.columns[[0,1,2]],axis=1)

# %%
ds.head()
# Out:
#     Profit  Unit_Price Shipping_Cost   Customer_Name Province   Region  \
# 0  -213.25       38.94            35           25000  Nunavut  Nunavut
# 1   457.81      208.16         68.02    Barry French  Nunavut  Nunavut
# 2  46.7075        8.69          2.99    Barry French  Nunavut  Nunavut
# 3  1198.97      195.99          3.99   Clay Rozendal  Nunavut  Nunavut
# 4    30.94       21.78          5.94  Carlos Soltero  Nunavut  Nunavut
#
#   Customer_Segment Product_Category            Product_Sub-Category  \
# 0   Small Business  Office Supplies          Storage & Organization
# 1         Consumer  Office Supplies                      Appliances
# 2         Consumer  Office Supplies  Binders and Binder Accessories
# 3        Corporate       Technology    Telephones and Communication
# 4         Consumer  Office Supplies                      Appliances
#
#                                            Prod_Name Product_Container  \
# ...

# %% [markdown]
# # Remove Rows

# %%
ds.head()
# Out:
#     Profit  Unit_Price Shipping_Cost   Customer_Name Province   Region  \
# 0  -213.25       38.94            35           25000  Nunavut  Nunavut
# 1   457.81      208.16         68.02    Barry French  Nunavut  Nunavut
# 2  46.7075        8.69          2.99    Barry French  Nunavut  Nunavut
# 3  1198.97      195.99          3.99   Clay Rozendal  Nunavut  Nunavut
# 4    30.94       21.78          5.94  Carlos Soltero  Nunavut  Nunavut
#
#   Customer_Segment Product_Category            Product_Sub-Category  \
# 0   Small Business  Office Supplies          Storage & Organization
# 1         Consumer  Office Supplies                      Appliances
# 2         Consumer  Office Supplies  Binders and Binder Accessories
# 3        Corporate       Technology    Telephones and Communication
# 4         Consumer  Office Supplies                      Appliances
#
#                                            Prod_Name Product_Container  \
# ...

# %%
ds=ds.drop([1])

# %%
ds.head()
# Out:
#     Profit  Unit_Price Shipping_Cost   Customer_Name Province   Region  \
# 0  -213.25       38.94            35           25000  Nunavut  Nunavut
# 2  46.7075        8.69          2.99    Barry French  Nunavut  Nunavut
# 3  1198.97      195.99          3.99   Clay Rozendal  Nunavut  Nunavut
# 4    30.94       21.78          5.94  Carlos Soltero  Nunavut  Nunavut
# 5     4.43     -456.00          4.95             NaN  Nunavut  Nunavut
#
#   Customer_Segment Product_Category            Product_Sub-Category  \
# 0   Small Business  Office Supplies          Storage & Organization
# 2         Consumer  Office Supplies  Binders and Binder Accessories
# 3        Corporate       Technology    Telephones and Communication
# 4         Consumer  Office Supplies                      Appliances
# 5         Consumer        Furniture              Office Furnishings
#
#                                            Prod_Name Product_Container  \
# ...

# %%
ds=ds.drop([0,4])

# %%
ds.head()
# Out:
#      Profit  Unit_Price Shipping_Cost  Customer_Name Province   Region  \
# 2   46.7075        8.69          2.99   Barry French  Nunavut  Nunavut
# 3   1198.97      195.99          3.99  Clay Rozendal  Nunavut  Nunavut
# 5      4.43     -456.00          4.95            NaN  Nunavut  Nunavut
# 6  -54.0385        7.30          7.72   Carl Jackson  Nunavut  Nunavut
# 7  ASD127.7       42.76          6.22   Carl Jackson  Nunavut  Nunavut
#
#   Customer_Segment Product_Category            Product_Sub-Category  \
# 2         Consumer  Office Supplies  Binders and Binder Accessories
# 3        Corporate       Technology    Telephones and Communication
# 5         Consumer        Furniture              Office Furnishings
# 6        Corporate  Office Supplies  Binders and Binder Accessories
# 7        Corporate  Office Supplies          Storage & Organization
#
#                                            Prod_Name Product_Container  \
# ...

# %%
ds=ds.drop(ds.index[:50])

# %%
ds.head()
# Out:
#      Profit  Unit_Price Shipping_Cost      Customer_Name Province   Region  \
# 53    -0.06        9.65          6.22        Frank Price  Nunavut  Nunavut
# 54  -50.325        7.99          5.03  Michelle Lonsdale  Nunavut  Nunavut
# 55  87.6775       58.10          1.49          Ann Chong  Nunavut  Nunavut
# 56   -68.22       80.48           4.5          Ann Chong  Nunavut  Nunavut
# 57   -354.9       92.23         39.61           Joy Bell  Nunavut  Nunavut
#
#    Customer_Segment Product_Category            Product_Sub-Category  \
# 53        Corporate        Furniture              Office Furnishings
# 54      Home Office       Technology    Telephones and Communication
# 55        Corporate  Office Supplies  Binders and Binder Accessories
# 56        Corporate  Office Supplies                      Appliances
# 57      Home Office        Furniture              Office Furnishings
#
#                                             Prod_Name Product_Container  \
# ...

# %%
ds.shape
# Out:
# (8346, 12)

# %%
ds=ds.drop(ds.index[99:200])

# %%
ds.shape
# Out:
# (8245, 12)

# %%
ds.head()
# Out:
#      Profit  Unit_Price Shipping_Cost      Customer_Name Province   Region  \
# 53    -0.06        9.65          6.22        Frank Price  Nunavut  Nunavut
# 54  -50.325        7.99          5.03  Michelle Lonsdale  Nunavut  Nunavut
# 55  87.6775       58.10          1.49          Ann Chong  Nunavut  Nunavut
# 56   -68.22       80.48           4.5          Ann Chong  Nunavut  Nunavut
# 57   -354.9       92.23         39.61           Joy Bell  Nunavut  Nunavut
#
#    Customer_Segment Product_Category            Product_Sub-Category  \
# 53        Corporate        Furniture              Office Furnishings
# 54      Home Office       Technology    Telephones and Communication
# 55        Corporate  Office Supplies  Binders and Binder Accessories
# 56        Corporate  Office Supplies                      Appliances
# 57      Home Office        Furniture              Office Furnishings
#
#                                             Prod_Name Product_Container  \
# ...

# %%
ds=ds.reset_index(drop=True)

# %%
ds.head()
# Out:
#     Profit  Unit_Price Shipping_Cost      Customer_Name Province   Region  \
# 0    -0.06        9.65          6.22        Frank Price  Nunavut  Nunavut
# 1  -50.325        7.99          5.03  Michelle Lonsdale  Nunavut  Nunavut
# 2  87.6775       58.10          1.49          Ann Chong  Nunavut  Nunavut
# 3   -68.22       80.48           4.5          Ann Chong  Nunavut  Nunavut
# 4   -354.9       92.23         39.61           Joy Bell  Nunavut  Nunavut
#
#   Customer_Segment Product_Category            Product_Sub-Category  \
# 0        Corporate        Furniture              Office Furnishings
# 1      Home Office       Technology    Telephones and Communication
# 2        Corporate  Office Supplies  Binders and Binder Accessories
# 3        Corporate  Office Supplies                      Appliances
# 4      Home Office        Furniture              Office Furnishings
#
#                                            Prod_Name Product_Container  \
# ...
