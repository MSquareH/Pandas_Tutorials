# %% [markdown]
# ## SET AND RESET INDEX IN PANDAS

# %%
 import pandas as pd 
import os

# %%
os.chdir('C:/Users/Moiz_Ali_Abedin/Desktop/Files of Pandas')

# %%
ds=pd.read_csv('Titanic Dataset.csv',index_col=0)

# %%
ds.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
#ds=ds.set_index('PassengerId')

# %%
ds.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
ds=ds.drop([2,3,5,8,10,12])

# %%
ds.head(20)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 4                   1       1
# 6                   0       3
# 7                   0       1
# 9                   1       3
# 11                  1       3
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# ...

# %%
ds=ds.reset_index(drop=True)

# %%
ds.head(20)
# Out:
#     Survived  Pclass                                               Name  \
# 0          0       3                            Braund, Mr. Owen Harris
# 1          1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 2          0       3                                   Moran, Mr. James
# 3          0       1                            McCarthy, Mr. Timothy J
# 4          1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 5          1       3                    Sandstrom, Miss. Marguerite Rut
# 6          0       3                     Saundercock, Mr. William Henry
# 7          0       3                        Andersson, Mr. Anders Johan
# 8          0       3               Vestrom, Miss. Hulda Amanda Adolfina
# 9          1       2                   Hewlett, Mrs. (Mary D Kingcome)
# 10         0       3                               Rice, Master. Eugene
# 11         1       2                       Williams, Mr. Charles Eugene
# ...
