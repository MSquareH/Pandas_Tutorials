# %% [markdown]
# ## Merging Dataframes

# %%
import pandas as pd
import os

# %%
os.chdir('C:/Users/Moiz_Ali_Abedin/Desktop/Files of Pandas')

# %%
ds1=pd.read_csv('Salesmen category Data for Pandas.csv')

# %%
ds1.head()
# Out:
#       RVS              RVS Name  RVS Channel   Channel Name
# 0  111353         SHAHEEN KAMAL           10  General Trade
# 1  111361  AL AMEEN MOHAMED IBR           10  General Trade
# 2  111710         ALI ALJAADARI           10  General Trade
# 3  111326      SALIM BA HASHWAN           10  General Trade
# 4  111729  NOUR ALAMIN ALI AHME           10  General Trade

# %%
ds2=pd.read_csv('sales for pandas2.csv')

# %%
ds2.head()
# Out:
#    Sales Office Branch Name      Date      Invoice     RVS       RVS Name  \
# 0          2100      Jeddah  16-03-16  11102617877  111353  SHAHEEN KAMAL
# 1          2100      Jeddah  16-03-16  11102617878  111353  SHAHEEN KAMAL
# 2          2100      Jeddah  16-03-16  11102617879  111353  SHAHEEN KAMAL
# 3          2100      Jeddah  16-03-16  11102617880  111353  SHAHEEN KAMAL
# 4          2100      Jeddah  16-03-16  11102617881  111353  SHAHEEN KAMAL
#
#    Customer         Customer Name Business Unit       Division   Sales
# 0    116695      TAMWENAAT KHALID          BU 1  FD30 - FOOD A  3211.0
# 1    116696      BAGALAT ALGHAITH          BU 1  FD30 - FOOD A  4505.0
# 2    122879  AL RAYYAN FOOD STUFF          BU 1  FD30 - FOOD A  1309.0
# 3    116737        TMWENATRA RAID          BU 1  FD30 - FOOD A  2588.0
# 4    119717        TAMWENAT RATAG          BU 1  FD30 - FOOD A  2004.0

# %%
ds_merged=pd.merge(ds1,ds2)

# %%
ds_merged.head()
# Out:
#       RVS       RVS Name  RVS Channel   Channel Name  Sales Office  \
# 0  111353  SHAHEEN KAMAL           10  General Trade          2100
# 1  111353  SHAHEEN KAMAL           10  General Trade          2100
# 2  111353  SHAHEEN KAMAL           10  General Trade          2100
# 3  111353  SHAHEEN KAMAL           10  General Trade          2100
# 4  111353  SHAHEEN KAMAL           10  General Trade          2100
#
#   Branch Name      Date      Invoice  Customer         Customer Name  \
# 0      Jeddah  16-03-16  11102617877    116695      TAMWENAAT KHALID
# 1      Jeddah  16-03-16  11102617878    116696      BAGALAT ALGHAITH
# 2      Jeddah  16-03-16  11102617879    122879  AL RAYYAN FOOD STUFF
# 3      Jeddah  16-03-16  11102617880    116737        TMWENATRA RAID
# 4      Jeddah  16-03-16  11102617881    119717        TAMWENAT RATAG
#
#   Business Unit       Division   Sales
# 0          BU 1  FD30 - FOOD A  3211.0
# 1          BU 1  FD30 - FOOD A  4505.0
# ...

# %%
ds_merged=pd.merge(ds1,ds2,on='RVS')

# %%
ds_merged.head()
# Out:
#       RVS     RVS Name_x  RVS Channel   Channel Name  Sales Office  \
# 0  111353  SHAHEEN KAMAL           10  General Trade          2100
# 1  111353  SHAHEEN KAMAL           10  General Trade          2100
# 2  111353  SHAHEEN KAMAL           10  General Trade          2100
# 3  111353  SHAHEEN KAMAL           10  General Trade          2100
# 4  111353  SHAHEEN KAMAL           10  General Trade          2100
#
#   Branch Name      Date      Invoice     RVS Name_y  Customer  \
# 0      Jeddah  16-03-16  11102617877  SHAHEEN KAMAL    116695
# 1      Jeddah  16-03-16  11102617878  SHAHEEN KAMAL    116696
# 2      Jeddah  16-03-16  11102617879  SHAHEEN KAMAL    122879
# 3      Jeddah  16-03-16  11102617880  SHAHEEN KAMAL    116737
# 4      Jeddah  16-03-16  11102617881  SHAHEEN KAMAL    119717
#
#           Customer Name Business Unit       Division   Sales
# 0      TAMWENAAT KHALID          BU 1  FD30 - FOOD A  3211.0
# 1      BAGALAT ALGHAITH          BU 1  FD30 - FOOD A  4505.0
# ...

# %%
ds1.head()
# Out:
#       RVS              RVS Name  RVS Channel   Channel Name
# 0  111353         SHAHEEN KAMAL           10  General Trade
# 1  111361  AL AMEEN MOHAMED IBR           10  General Trade
# 2  111710         ALI ALJAADARI           10  General Trade
# 3  111326      SALIM BA HASHWAN           10  General Trade
# 4  111729  NOUR ALAMIN ALI AHME           10  General Trade

# %%
ds2.head()
# Out:
#    Sales Office Branch Name      Date      Invoice     RVS       RVS Name  \
# 0          2100      Jeddah  16-03-16  11102617877  111353  SHAHEEN KAMAL
# 1          2100      Jeddah  16-03-16  11102617878  111353  SHAHEEN KAMAL
# 2          2100      Jeddah  16-03-16  11102617879  111353  SHAHEEN KAMAL
# 3          2100      Jeddah  16-03-16  11102617880  111353  SHAHEEN KAMAL
# 4          2100      Jeddah  16-03-16  11102617881  111353  SHAHEEN KAMAL
#
#    Customer         Customer Name Business Unit       Division   Sales
# 0    116695      TAMWENAAT KHALID          BU 1  FD30 - FOOD A  3211.0
# 1    116696      BAGALAT ALGHAITH          BU 1  FD30 - FOOD A  4505.0
# 2    122879  AL RAYYAN FOOD STUFF          BU 1  FD30 - FOOD A  1309.0
# 3    116737        TMWENATRA RAID          BU 1  FD30 - FOOD A  2588.0
# 4    119717        TAMWENAT RATAG          BU 1  FD30 - FOOD A  2004.0

# %%
ds1=ds1.rename(columns={'RVS':'RVS1'})

# %%
ds1.head()
# Out:
#      RVS1              RVS Name  RVS Channel   Channel Name
# 0  111353         SHAHEEN KAMAL           10  General Trade
# 1  111361  AL AMEEN MOHAMED IBR           10  General Trade
# 2  111710         ALI ALJAADARI           10  General Trade
# 3  111326      SALIM BA HASHWAN           10  General Trade
# 4  111729  NOUR ALAMIN ALI AHME           10  General Trade

# %%
ds2.head()
# Out:
#    Sales Office Branch Name      Date      Invoice     RVS       RVS Name  \
# 0          2100      Jeddah  16-03-16  11102617877  111353  SHAHEEN KAMAL
# 1          2100      Jeddah  16-03-16  11102617878  111353  SHAHEEN KAMAL
# 2          2100      Jeddah  16-03-16  11102617879  111353  SHAHEEN KAMAL
# 3          2100      Jeddah  16-03-16  11102617880  111353  SHAHEEN KAMAL
# 4          2100      Jeddah  16-03-16  11102617881  111353  SHAHEEN KAMAL
#
#    Customer         Customer Name Business Unit       Division   Sales
# 0    116695      TAMWENAAT KHALID          BU 1  FD30 - FOOD A  3211.0
# 1    116696      BAGALAT ALGHAITH          BU 1  FD30 - FOOD A  4505.0
# 2    122879  AL RAYYAN FOOD STUFF          BU 1  FD30 - FOOD A  1309.0
# 3    116737        TMWENATRA RAID          BU 1  FD30 - FOOD A  2588.0
# 4    119717        TAMWENAT RATAG          BU 1  FD30 - FOOD A  2004.0

# %%
ds_merged=pd.merge(ds1,ds2,left_on='RVS1',right_on='RVS')

# %%
ds_merged.head()
# Out:
#      RVS1     RVS Name_x  RVS Channel   Channel Name  Sales Office  \
# 0  111353  SHAHEEN KAMAL           10  General Trade          2100
# 1  111353  SHAHEEN KAMAL           10  General Trade          2100
# 2  111353  SHAHEEN KAMAL           10  General Trade          2100
# 3  111353  SHAHEEN KAMAL           10  General Trade          2100
# 4  111353  SHAHEEN KAMAL           10  General Trade          2100
#
#   Branch Name      Date      Invoice     RVS     RVS Name_y  Customer  \
# 0      Jeddah  16-03-16  11102617877  111353  SHAHEEN KAMAL    116695
# 1      Jeddah  16-03-16  11102617878  111353  SHAHEEN KAMAL    116696
# 2      Jeddah  16-03-16  11102617879  111353  SHAHEEN KAMAL    122879
# 3      Jeddah  16-03-16  11102617880  111353  SHAHEEN KAMAL    116737
# 4      Jeddah  16-03-16  11102617881  111353  SHAHEEN KAMAL    119717
#
#           Customer Name Business Unit       Division   Sales
# 0      TAMWENAAT KHALID          BU 1  FD30 - FOOD A  3211.0
# ...
